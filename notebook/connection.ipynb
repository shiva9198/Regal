# %%
# %pip install neo4j
# Out:
# Collecting neo4j
#   Using cached neo4j-5.28.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from neo4j) (2025.2)
# Using cached neo4j-5.28.1-py3-none-any.whl (312 kB)
# Installing collected packages: neo4j
# Successfully installed neo4j-5.28.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from neo4j import GraphDatabase

uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "123456789"))

# %%
import json
# === Function to delete all existing data (optional cleanup) ===
def delete_all_data(tx):
    tx.run("MATCH (n) DETACH DELETE n")
    print("🗑️ Cleared existing data.")

# === Function to insert data from JSON triples ===
def insert_triple(tx, subject, predicate, obj):
    query = (
        "MERGE (a:Entity {name: $subject}) "
        "MERGE (b:Entity {name: $object}) "
        "MERGE (a)-[r:RELATION {type: $predicate}]->(b)"
    )
    tx.run(query, subject=subject, object=obj, predicate=predicate)
    print(f"✅ Inserted: ({subject}) -[{predicate}]-> ({obj})")

# === Load JSON triples ===
with open("/Users/shiva/Documents/Regal/data/knowledge_graph_triples.json", "r") as f:
    triples = json.load(f)

# === Insert all triples into Neo4j ===
with driver.session() as session:
    # Uncomment this to wipe the DB before inserting
    session.write_transaction(delete_all_data)

    for triple in triples:
        session.write_transaction(
            insert_triple,
            triple["subject"],
            triple["predicate"],
            triple["object"]
        )

print("✅ All triples inserted into Neo4j.")

# === Close connection ===
driver.close()
# Out:
# /var/folders/sp/bpt4yr7512j5sybsn3m_q32w0000gn/T/ipykernel_9032/3263358549.py:24: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(delete_all_data)
# /var/folders/sp/bpt4yr7512j5sybsn3m_q32w0000gn/T/ipykernel_9032/3263358549.py:27: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(
# 🗑️ Cleared existing data.
# ✅ Inserted: (Reserve Bank of India) -[is located in]-> (Mumbai 400 001)
# ✅ Inserted: (Reserve Bank of India) -[issued]-> (No. FEMA 400/2022-RB)
# ✅ Inserted: (No. FEMA 400/2022-RB) -[is dated]-> (August 22, 2022)
# ✅ Inserted: (Reserve Bank of India) -[exercises powers conferred by]-> (sub -section (1) and clause (a) of sub -section (2) of section 47 of the Foreign Exchange Management Act, 1999 (42 of 1999))
# ✅ Inserted: (Reserve Bank of India) -[makes]-> (Foreign Exchange Management (Overseas Investment) Regulations, 2022)
# ✅ Inserted: (These regulations) -[may be called]-> (the Foreign Exchange Management (Overasas Investment) Regulations, 2022)
# ✅ Inserted: (They) -[shall come into force on]-> (the date of their publication in the Official Gazette)
# ✅ Inserted: (Act) -[means]-> (the Foreign Exchange Management Act, 1999 (42 of 1999))
# ✅ Inserted: (debt instruments) -[have the same meaning as assigned to it in]-> (the Foreign Exchange Management (Overseas Investment) Rules, 2022)
# ✅ Inserted: (The words and expressions used but not defined in these regulations) -[shall have the meanings respectively assigned to them in]-> (the Act or the Foreign Exchange Management (Overseas Investment) Rules, 2022)
# ✅ Inserted: (Financial commitment by Indian entity by modes other than equity capital) -[is related to]-> (The Indian entity)
# ✅ Inserted: (Indian entity) -[may lend or invest in]-> (any debt instrument issued by a foreign entity)
# ✅ Inserted: (Indian entity) -[may extend]-> (non-fund based commitment to or on behalf of a foreign entity)
# ✅ Inserted: (Indian entity) -[may extend]-> (non-fund based commitment to overseas step down subsidiaries of such Indian entity)
# ✅ Inserted: (Indian entity) -[is subject to]-> (the following conditions within the financial commitment limit as prescribed in the Foreign Exchange Management (Overseas Investment) Rules, 2022)
# ✅ Inserted: (Indian entity) -[is eligible to make]-> (Overseas Direct Investment (ODI))
# ✅ Inserted: (the Indian entity) -[has made]-> (ODI in the foreign entity)
# ✅ Inserted: (the Indian entity) -[has acquired]-> (control in such foreign entity)
# ✅ Inserted: (The financial commitments) -[shall be reckoned towards]-> (the financial commitment limit)
# ✅ Inserted: (An Indian entity) -[may lend or invest in]-> (debt instruments issued by a foreign entity)
# ✅ Inserted: (Such loans) -[are backed by]-> (a loan agreement)
# ✅ Inserted: (The rate of interest) -[shall be charged on]-> (an arm's length basis)
# ✅ Inserted: (transaction) -[is between]-> (two related parties)
# ✅ Inserted: (transaction) -[is conducted as if]-> (they were unrelated)
# ✅ Inserted: (transaction) -[prevents]-> (conflict of interest)
# ✅ Inserted: (Financial commitment) -[may be issued to or on behalf of]-> (the foreign entity)
# ✅ Inserted: (Financial commitment) -[may be issued to or on behalf of]-> (any of its step down subsidiary)
# ✅ Inserted: (Indian entity) -[has acquired control through]-> (the foreign entity)
# ✅ Inserted: (corporate or performance guarantee) -[may be issued by]-> (such Indian entity)
# ✅ Inserted: (corporate or performance guarantee) -[is by]-> (a group company of such Indian entity in India)
# ✅ Inserted: (group company) -[is]-> (a holding company)
# ✅ Inserted: (holding company) -[holds]-> (at least 51 per cent. stake in the Indian entity)
# ✅ Inserted: (group company) -[is]-> (a subsidiary company)
# ✅ Inserted: (subsidiary company) -[is in which]-> (the Indian entity holds at least 51 per cent. stake)
# ✅ Inserted: (group company) -[is]-> (a promoter group company)
# ✅ Inserted: (promoter group company) -[is]-> (a body corporate)
# ✅ Inserted: (personal guarantee) -[is by]-> (the resident individual promoter of such an Indian entity)
# ✅ Inserted: (bank guarantee) -[is backed by]-> (a counter -guarantee or collateral by the Indian entity or its group company)
# ✅ Inserted: (bank guarantee) -[is issued by]-> (a bank in India)
# ✅ Inserted: (guarantee) -[is extended by]-> (a group company)
# ✅ Inserted: (guarantee) -[shall be counted towards]-> (the utilisation of its financial commitment limit independently)
# ✅ Inserted: (guarantee) -[shall be counted towards]-> (the financial commitment limit of the Indian entity)
# ✅ Inserted: (commitment under sub-regulation (1)) -[is extended by]-> (group company)
# ✅ Inserted: (fund-based exposure) -[is deducted from]-> (net worth of group company)
# ✅ Inserted: (guarantee under sub-regulation (1)) -[is extended by]-> (promoter)
# ✅ Inserted: (Indian entity) -[shall be a part of]-> (promoter group)
# ✅ Inserted: (the expression “promoter group”) -[shall have the meaning as assigned to it in]-> (the Securities and Exchange Board of India (Issue of Capital and Disclosure Requirements) Regulations 2018)
# ✅ Inserted: (No guarantee) -[shall be]-> (open-ended)
# ✅ Inserted: (The guarantee) -[shall cease to be a part of]-> (the non- fund based commitment)
# ✅ Inserted: (The guarantee) -[be considered as]-> (lending)
# ✅ Inserted: (a guarantee) -[has been extended jointly and severally by]-> (two or more Indian entities)
# ✅ Inserted: (100 per cent. of the amount of such guarantee) -[shall be reckoned towards]-> (the individual limits of each of such Indian entities)
# ✅ Inserted: (In case of performance guarantee) -[50 per cent. of the amount of guarantee shall be reckoned towards]-> (the financial commitment limit)
# ✅ Inserted: (Roll-over of guarantee) -[shall not be treated as]-> (fresh financial commitment)
# ✅ Inserted: (Roll-over of guarantee) -[does not exceed]-> (the amount of original guarantee)
# ✅ Inserted: (Indian entity) -[has made]-> (ODI)
# ✅ Inserted: (Indian entity) -[may pledge]-> (the equity capital of the foreign entity)
# ✅ Inserted: (Indian entity) -[has made]-> (investment in equity capital in a foreign entity)
# ✅ Inserted: (subsidiary outside India) -[held directly by]-> (the Indian entity)
# ✅ Inserted: (Indian entity) -[held indirectly in]-> (step down subsidiary)
# ✅ Inserted: (step down subsidiary) -[in favour of]-> (AD bank)
# ✅ Inserted: (step down subsidiary) -[in favour of]-> (public financial institution in India)
# ✅ Inserted: (step down subsidiary) -[in favour of]-> (overseas lender)
# ✅ Inserted: (step down subsidiary) -[for availing]-> (fund based facilities)
# ✅ Inserted: (step down subsidiary) -[for availing]-> (non-fund based facilities)
# ✅ Inserted: (step down subsidiary) -[in favour of]-> (debenture trustee registered with SEBI)
# ✅ Inserted: (debenture trustee registered with SEBI) -[for availing]-> (fund based facilities)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (its assets in India)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (the assets of its group company)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (associate company)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (promoter)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (director)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (assets in favour of an AD bank)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (public financial institution in India)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (overseas lender)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (security for availing of the fund based or non- fund based facility)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (any foreign entity in which it has made ODI)
# ✅ Inserted: (it) -[create charge by way of mortgage, pledge, hypothecation or any other identical mode on]-> (its step down subsidiary outside India)
# ✅ Inserted: (the assets outside India of the foreign entity) -[has made]-> (ODI)
# ✅ Inserted: (the assets outside India of the foreign entity) -[has made]-> (step down subsidiary outside India)
# ✅ Inserted: (the assets outside India of the foreign entity) -[in favour of]-> (an AD bank in India)
# ✅ Inserted: (the assets outside India of the foreign entity) -[in favour of]-> (a public financial institution in India)
# ✅ Inserted: (the assets outside India of the foreign entity) -[used as security for]-> (the fund based or non -fund based facility)
# ✅ Inserted: (the assets outside India of the foreign entity) -[used as security for]-> (itself)
# ✅ Inserted: (the assets outside India of the foreign entity) -[used as security for]-> (any foreign entity in which it has made ODI)
# ✅ Inserted: (the assets outside India of the foreign entity) -[used as security for]-> (its step down subsidiary outside India)
# ✅ Inserted: (the assets outside India of the foreign entity) -[in favour of]-> (a debenture trustee registered with SEBI in India)
# ✅ Inserted: (the assets outside India of the foreign entity) -[used for]-> (availing fund based facilities)
# ✅ Inserted: (the value of the pledge or charge or the amount of the facility) -[shall be reckoned towards]-> (the financial commitment limit in force at the time of such pledge or charge)
# ✅ Inserted: (overseas lender) -[shall not be from]-> (any)
# ✅ Inserted: (country or jurisdiction) -[is not permissible under]-> (the Foreign Exchange Management (Overseas Investment) Rules, 2022)
# ✅ Inserted: (the creation or enforcement of such pledge or charge) -[shall be in accordance with]-> (the provisions of the Act or rules or regulations made or directions issued thereunder)
# ✅ Inserted: (the expression 'public financial institution') -[shall have]-> (the same meaning as assigned to it)
# ✅ Inserted: (clause (72) of section 2) -[is under]-> (the Companies Act, 2013 (18 of 2013))
# ✅ Inserted: (the negative pledge or negative charge) -[created by]-> (an Indian entity or a bid bond guarantee)
# ✅ Inserted: (the negative pledge or negative charge) -[obtained in accordance with]-> (these regulations)
# ✅ Inserted: (the negative pledge or negative charge) -[participation in]-> (a bidding or tender procedure)
# ✅ Inserted: (the negative pledge or negative charge) -[shall not be reckoned towards]-> (the financial commitment limit)
# ✅ Inserted: (Acquisition or transfer) -[by way of]-> (deferred payment)
# ✅ Inserted: (a person) -[resident in]-> (India)
# ✅ Inserted: (person resident outside India) -[acquires equity capital]-> (by way of subscription to an issue)
# ✅ Inserted: (person resident outside India) -[acquires equity capital]-> (by way of purchase from a person resident outside India)
# ✅ Inserted: (person resident outside India) -[acquires equity capital]-> (from a person resident in India)
# ✅ Inserted: (equity capital) -[is reckoned as]-> (ODI)
# ✅ Inserted: (payment of amount of consideration) -[may be deferred for]-> (such definite period from the date of the)
# ✅ Inserted: (the foreign securities equivalent) -[be transferred or issued]-> (upfront by the seller to the buyer)
# ✅ Inserted: (the full consideration) -[be compliant with]-> (the applicable pricing guidelines)
# ✅ Inserted: (the deferred part of the consideration) -[be in case of]-> (acquisition of equity capital)
# ✅ Inserted: (foreign entity) -[be treated by]-> (a person resident in India)
# ✅ Inserted: (buyer) -[may be indemnified by]-> (the seller)
# ✅ Inserted: (agreement) -[is in compliance with]-> (the provisions of the Act)
# ✅ Inserted: (agreement) -[is in compliance with]-> (the rules and regulations made thereunder)
# ✅ Inserted: (A person resident in India making Overseas Investment) -[may make payment]-> (by remittance made through banking channels)
# ✅ Inserted: (A person resident in India making Overseas Investment) -[may make payment]-> (from funds held in an account maintained in accordance with the provisions of the Act)
# ✅ Inserted: (A person resident in India making Overseas Investment) -[may make payment]-> (by swap of securities)
# ✅ Inserted: (A person resident in India making Overseas Investment) -[may make payment]-> (by using the proceeds of American Depository Receipts or Global Depositary Receipts or stock)
# ✅ Inserted: (swap) -[raised in accordance with]-> (provisions of the Act and the rules and regulations)
# ✅ Inserted: (Indian entity) -[making]-> (ODI or financial commitment by way of debt)
# ✅ Inserted: (person resident in India) -[acquiring]-> (equity capital in a foreign entity)
# ✅ Inserted: (equity capital in a foreign entity) -[is reckoned as]-> (ODI)
# ✅ Inserted: (person resident in India) -[submit to]-> (the AD bank share certificates or any other)
# ✅ Inserted: (relevant documents) -[as per]-> (the applicable laws of the host country or the host jurisdiction)
# ✅ Inserted: (such investment) -[in]-> (the foreign entity)
# ✅ Inserted: (such investment) -[within]-> (six months from the date of effecting remittance or the date on which the dues to such person are capitalised or the date on which the amount due was allowed to be capitalised)
# ✅ Inserted: (A person resident in India) -[shall obtain]-> (a Unique Identification Number or UIN from the Reserve Bank)
# ✅ Inserted: (A person resident in India) -[shall obtain]-> (UIN for the foreign entity)
# ✅ Inserted: (A person resident in India) -[intends to make]-> (ODI)
# ✅ Inserted: (A person resident in India) -[shall send]-> (outward remittance or acquisition of equity capital in a foreign entity)
# ✅ Inserted: (A person resident in India making ODI) -[shall designate]-> (an AD bank)
# ✅ Inserted: (A person resident in India making ODI) -[shall route]-> (all transactions relating to a particular UIN through such AD)
# ✅ Inserted: (more than one person resident in India) -[makes]-> (financial commitment in the same foreign entity)
# ✅ Inserted: (all such persons) -[shall route]-> (all transactions relating to that UIN through the AD bank designated for that UIN)
# ✅ Inserted: (A person resident in India having ODI in a foreign entity) -[shall realise and repatriate to India]-> (all dues receivable from the foreign entity with respect to investment in such foreign)
# ✅ Inserted: (entity) -[received]-> (consideration on account of transfer or disinvestment of ODI)
# ✅ Inserted: (entity) -[realises]-> (net value of the assets on account of the liquidation of the foreign entity)
# ✅ Inserted: (entity) -[follows]-> (laws of the host country or the host jurisdiction)
# ✅ Inserted: (entity) -[has to do it within]-> (ninety days from the date when such receivables fall due or the date of such transfer or disinvestment or the date of the actual distribution of assets)
# ✅ Inserted: (assets) -[made by]-> (the official liquidator)
# ✅ Inserted: (A person resident in India) -[is eligible to make]-> (ODI)
# ✅ Inserted: (A person resident in India) -[may make remittance towards]-> (earnest money deposit)
# ✅ Inserted: (A person resident in India) -[may obtain]-> (a bid bond guarantee from an AD bank)
# ✅ Inserted: (A person resident in India) -[may participate in]-> (bidding or tender procedure for the acquisition of a foreign entity)
# ✅ Inserted: (An open-ended bid bond guarantee) -[shall be converted into]-> (a close-ended guarantee)
# ✅ Inserted: (Conversion of open-ended bid bond guarantee into close-ended guarantee) -[should not be later than]-> (three months from the date of award of the contract)
# ✅ Inserted: (Reporting requirements) -[is for]-> (Overseas Investment)
# ✅ Inserted: (a person resident in India) -[shall make all reporting]-> (through the designated AD bank)
# ✅ Inserted: (reporting) -[is in]-> (the manner provided in this regulation)
# ✅ Inserted: (reporting) -[is in]-> (the format provided by the Reserve Bank)
# ✅ Inserted: (A person resident in India) -[has made]-> (ODI)
# ✅ Inserted: (A person resident in India) -[is making]-> (financial commitment)
# ✅ Inserted: (A person resident in India) -[is undertaking]-> (disinvestment in a foreign entity)
# ✅ Inserted: (A person resident in India) -[shall report]-> (the following)
# ✅ Inserted: (financial commitment) -[is reckoned towards]-> (the financial commitment limit)
# ✅ Inserted: (person resident in India) -[making]-> (Overseas Portfolio Investment)
# ✅ Inserted: (disinvestment) -[within]-> (thirty days of receipt of disinvestment proceeds)
# ✅ Inserted: (restructuring) -[within]-> (thirty days from the date of such restructuring)
# ✅ Inserted: (OPI) -[report]-> (investment or transfer of investment within sixty days)
# ✅ Inserted: (OPI) -[report]-> (transfer by way of sale)
# ✅ Inserted: (OPI) -[made]-> (investment or transfer as of September or March-end)
# ✅ Inserted: (office in India) -[do]-> (reporting in case of OPI by way of acquisition of shares or interest under Employee Stock Ownership Plan or Employee Benefits Scheme)
# ✅ Inserted: (branch of an overseas entity) -[is in]-> (India)
# ✅ Inserted: (subsidiary in India) -[is of]-> (an overseas entity)
# ✅ Inserted: (the Indian entity) -[has]-> (direct or indirect equity holding)
# ✅ Inserted: (resident individual) -[is]-> (an employee or director)
# ✅ Inserted: (A person resident in India) -[acquiring]-> (equity capital in a foreign entity)
# ✅ Inserted: (equity capital in a foreign entity) -[is reckoned as]-> (ODI)
# ✅ Inserted: (person resident in India) -[shall submit]-> (an Annual Performance Report)
# ✅ Inserted: (Annual Performance Report) -[is with respect to]-> (each foreign entity)
# ✅ Inserted: (Annual Performance Report) -[is submitted every year by]-> (31st)
# ✅ Inserted: (foreign entity) -[ends accounting year on]-> (31st December)
# ✅ Inserted: (APR) -[shall be submitted by]-> (31st December of the next year)
# ✅ Inserted: (person resident in India) -[is holding less than]-> (10 per cent of the equity capital)
# ✅ Inserted: (person resident in India) -[has no other financial commitment other than]-> (equity capital)
# ✅ Inserted: (foreign entity) -[is under]-> (liquidation)
# ✅ Inserted: (the APR) -[shall be based on]-> (the audited financial statements of the foreign entity)
# ✅ Inserted: (the person resident in India) -[does not have]-> (control in the foreign entity)
# ✅ Inserted: (the laws of the host country or host jurisdiction) -[do not provide for]-> (mandatory auditing of the books of accounts)
# ✅ Inserted: (the APR) -[may be submitted based on]-> (unaudited financial statements)
# ✅ Inserted: (statutory auditor) -[certified]-> (Indian entity)
# ✅ Inserted: (chartered accountant) -[certified]-> (Indian entity)
# ✅ Inserted: (person) -[made]-> (ODI)
# ✅ Inserted: (person) -[holding]-> (highest stake in the foreign entity)
# ✅ Inserted: (person) -[required]-> (to submit APR)
# ✅ Inserted: (holdings) -[being]-> (equal)
# ✅ Inserted: (APR) -[may be filed jointly by]-> (such persons)
# ✅ Inserted: (the person resident in India) -[shall report]-> (the details regarding acquisition or setting up or winding up or transfer of a step down subsidiary or alteration in the shareholding pattern in the foreign entity during the reporting year in the APR)
# ✅ Inserted: (An Indian entity) -[has made]-> (ODI)
# ✅ Inserted: (An Indian entity) -[shall submit]-> (an Annual Return on Foreign Liabilities and Assets)
# ✅ Inserted: (the Reserve Bank) -[may decide]-> (such time)
# ✅ Inserted: (An Indian entity) -[submit to]-> (the Department of)
# ✅ Inserted: (A person resident in India) -[does not submit]-> (the evidence of investment within the time specified under sub -regulation (1) of regulation 9)
# ✅ Inserted: (A person resident in India) -[does not make]-> (any filing within the time specified under regulation 10)
# ✅ Inserted: (A person resident in India) -[may make]-> (such submission or filing)
# ✅ Inserted: (A person resident in India) -[may make]-> (Late Submission Fee within such period)
# ✅ Inserted: (Late Submission Fee) -[may be advised]-> (at the rates and in the manner)
# ✅ Inserted: (facility) -[can be availed within]-> (a maximum period of three years)
# ✅ Inserted: (facility) -[be directed by]-> (the Reserve Bank)
# ✅ Inserted: (A person resident in India) -[is responsible for]-> (submitting the evidence or any filing relating to overseas investment)
# ✅ Inserted: (A person resident in India) -[is responsible for]-> (submitting in accordance with the Act or regulations made thereunder before the date of publication of these regulations)
# ✅ Inserted: (A person resident in India) -[has not made or does not make]-> (such submission or filing within the time specified thereunder)
# ✅ Inserted: (A person resident in India) -[may make]-> (such submission or filing along with Late)
# ✅ Inserted: (Submission Fee) -[done within period]-> (advised)
# ✅ Inserted: (Submission Fee) -[done at rates]-> (directed by the Reserve Bank)
# ✅ Inserted: (Submission Fee) -[done in manner]-> (directed by the Reserve Bank)
# ✅ Inserted: (facility) -[can be availed within]-> (maximum period of three years)
# ✅ Inserted: (regulations) -[published in]-> (Official Gazette)
# ✅ Inserted: (A person resident in India) -[has made]-> (a financial commitment in a foreign entity)
# ✅ Inserted: (A person resident in India) -[shall not make]-> (any further financial commitment)
# ✅ Inserted: (A person resident in India) -[shall not make]-> (any transfer such investment)
# ✅ Inserted: (Ajay Kumar Misra) -[is]-> (Chief General Manager-in-Charge)
# ✅ Inserted: (Chief General Manager-in-Charge) -[Published in]-> (the Official Gazette of Government of India)
# ✅ Inserted: (Official Gazette) -[is of]-> (Government of India)
# ✅ Inserted: (Official Gazette) -[is]-> (Extraordinary – Part-III, Section 4)
# ✅ Inserted: (Official Gazette) -[has]-> (Gazette ID CG-MH-E-22082022-238242)
# ✅ Inserted: (Gazette ID CG-MH-E-22082022-238242) -[dated]-> (August 22, 2022)
# ✅ All triples inserted into Neo4j.

# %%
import json


# === Function to delete all existing data (optional cleanup) ===
def delete_all_data(tx):
    tx.run("MATCH (n) DETACH DELETE n")
    print("🗑️ Cleared existing data.")

# === Function to insert an entity ===
def insert_entity(tx, name, entity_type, singular, description):
    query = (
        "MERGE (e:Entity {name: $name}) "
        "SET e.entity_type = $entity_type, e.singular = $singular, e.description = $description"
    )
    tx.run(query, name=name, entity_type=entity_type, singular=singular, description=description)
    print(f"✅ Inserted Entity: {name}")

# === Function to insert a relationship ===
def insert_relationship(tx, entity_1, entity_2, rel_type, description):
    query = (
        "MATCH (a:Entity {name: $entity_1}), (b:Entity {name: $entity_2}) "
        "MERGE (a)-[r:RELATION {type: $rel_type, description: $description}]->(b)"
    )
    tx.run(query, entity_1=entity_1, entity_2=entity_2, rel_type=rel_type, description=description)
    print(f"🔗 Created Relationship: ({entity_1})-[:{rel_type}]->({entity_2})")

# === Load JSON data ===
with open("/Users/shiva/Documents/Regal/data/enities_realtions.json", "r") as f:
    kg_data = json.load(f)

# === Insert all entities and relationships into Neo4j ===
with driver.session() as session:
    # Optional: Wipe database before inserting new data
    session.write_transaction(delete_all_data)

    # Insert entities
    for entity in kg_data["entities"]:
        session.write_transaction(
            insert_entity,
            entity["name"],
            entity["entity_type"],
            entity["singular"],
            entity["description"]
        )

    # Insert relationships
    for rel in kg_data["relationships"]:
        session.write_transaction(
            insert_relationship,
            rel["entity_1"],
            rel["entity_2"],
            rel["relationship_type"],
            rel["description"]
        )

print("✅ All entities and relationships inserted into Neo4j.")

# === Close connection ===
driver.close()
# Out:
# /var/folders/sp/bpt4yr7512j5sybsn3m_q32w0000gn/T/ipykernel_9032/246818510.py:32: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# /var/folders/sp/bpt4yr7512j5sybsn3m_q32w0000gn/T/ipykernel_9032/246818510.py:34: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(delete_all_data)
# 🗑️ Cleared existing data.
# /var/folders/sp/bpt4yr7512j5sybsn3m_q32w0000gn/T/ipykernel_9032/246818510.py:38: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(
# /var/folders/sp/bpt4yr7512j5sybsn3m_q32w0000gn/T/ipykernel_9032/246818510.py:48: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(
# ✅ Inserted Entity: foreign_exchange_management_act_1999
# ✅ Inserted Entity: foreign_exchange_management_overseas_investment_rules_2022
# ✅ Inserted Entity: authorised_dealer_bank
# ✅ Inserted Entity: overseas_direct_investment
# ✅ Inserted Entity: overseas_portfolio_investment
# ✅ Inserted Entity: reserve_bank
# ✅ Inserted Entity: international_financial_services_centre
# ✅ Inserted Entity: strategic_sector
# 🔗 Created Relationship: (foreign_exchange_management_overseas_investment_rules_2022)-[:framed_under]->(foreign_exchange_management_act_1999)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# 🔗 Created Relationship: (reserve_bank)-[:administers]->(foreign_exchange_management_overseas_investment_rules_2022)
# ✅ All entities and relationships inserted into Neo4j.
